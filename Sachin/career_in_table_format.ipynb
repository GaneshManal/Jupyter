# %%
import pandas as pd

df = pd.read_csv('odi_career.csv')

# %%
print df.size, df.shape
# Out:
# 5556 (463, 12)

# %%
df
# Out:
#     batting_score wickets runs_conceded catches stumps    opposition  \
# 0               0       -             -       0      0      Pakistan
# 1               0       -             -       0      0   New_Zealand
# 2              36       -             -       0      0   New_Zealand
# 3              10       -             -       1      0     Sri_Lanka
# 4              20       -             -       0      0      Pakistan
# 5              19       -             -       0      0       England
# 6              31       0            10       0      0       England
# 7              36       -             -       0      0     Sri_Lanka
# 8              53       2            39       2      0     Sri_Lanka
# 9              30       -             -       0      0     Sri_Lanka
# 10            DNB       0            15       0      0    Bangladesh
# 11              4       -             -       0      0     Sri_Lanka
# 12             53       -             -       0      0     Sri_Lanka
# ...
